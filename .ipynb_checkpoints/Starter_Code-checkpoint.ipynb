# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df_clean = application_df.drop(columns=['EIN','NAME'])

# %%
# Determine the number of unique values in each column.
application_df_clean.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df_clean['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=['T9','T13','T12','T2','T25','T14','T29','T15','T17']
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df_clean['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
value_counts = application_df_clean['CLASSIFICATION'].value_counts()
filtered_value_counts = value_counts[value_counts > 1]
filtered_value_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
value_counts = application_df_clean['CLASSIFICATION'].value_counts()
filtered_value_counts = value_counts[value_counts <= 777]
fv_df = filtered_value_counts.reset_index()
classifications_to_replace = list(fv_df['CLASSIFICATION'])

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
df_dummy = pd.get_dummies(application_df_clean)
df_dummy
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                  True
# 1           1    108590              1                 False
# 2           1      5000              0                 False
# 3           1      6692              1                 False
# 4           1    142590              1                 False
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                 False
# 34295       1      5000              0                 False
# 34296       1      5000              0                 False
# 34297       1      5000              1                 False
# 34298       1  36500179              0                 False
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                     False                 False                 False
# 1                     False                 False                 False
# ...

# %%
y = df_dummy['IS_SUCCESSFUL'].values
y
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
# Split our preprocessed data into our features and target arrays
X = df_dummy.drop('IS_SUCCESSFUL', axis=1).values
X
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# (FIRST ATTEMPT - ACCURACY 72%) 
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer. 
input_features_total = len(X_train[0]) 
hidden_nodes_layer1 = 20 
hidden_nodes_layer2 = 20 
nn = tf.keras.models.Sequential() 
# First hidden layer 
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim = input_features_total, activation = "relu")) 
# Second hidden layer 
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation = "relu")) 
# Output layer 
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid")) 
# Check the structure of the model nn.summary()

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE

# Second hidden layer
#  YOUR CODE GOES HERE

# Output layer
#  YOUR CODE GOES HERE

# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:From Z:\Travis\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 80)                3520
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                2430
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# ...
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5861 - accuracy: 0.7118
# Epoch 2/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5551 - accuracy: 0.7292
# Epoch 3/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5495 - accuracy: 0.7310
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5475 - accuracy: 0.7322
# Epoch 5/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5464 - accuracy: 0.7324
# Epoch 6/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5450 - accuracy: 0.7321
# Epoch 7/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5444 - accuracy: 0.7339
# Epoch 8/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7340
# Epoch 9/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7338
# Epoch 10/50
# ...

# %%
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 20)                2340
#
#  dense_7 (Dense)             (None, 20)                420
#
#  dense_8 (Dense)             (None, 1)                 21
#
# ...
# Total params: 2781 (10.86 KB)
# Trainable params: 2781 (10.86 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
# Out:
# WARNING:tensorflow:From Z:\Travis\anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Train the model
#  YOUR CODE GOES HERE
# Out:
# Epoch 1/100
# 25724/25724 [==============================] - 2s 80us/sample - loss: 0.5700 - acc: 0.7234
# Epoch 2/100
# 25724/25724 [==============================] - 1s 44us/sample - loss: 0.5556 - acc: 0.7294
# Epoch 3/100
# 25724/25724 [==============================] - 1s 43us/sample - loss: 0.5529 - acc: 0.7304
# Epoch 4/100
# 25724/25724 [==============================] - 1s 49us/sample - loss: 0.5514 - acc: 0.7318
# Epoch 5/100
# 25724/25724 [==============================] - 1s 48us/sample - loss: 0.5495 - acc: 0.7322
# Epoch 6/100
# 25724/25724 [==============================] - 1s 46us/sample - loss: 0.5488 - acc: 0.7330
# Epoch 7/100
# 25724/25724 [==============================] - 1s 47us/sample - loss: 0.5482 - acc: 0.7335
# Epoch 8/100
# 25724/25724 [==============================] - 1s 44us/sample - loss: 0.5475 - acc: 0.7326
# Epoch 9/100
# 25724/25724 [==============================] - 1s 48us/sample - loss: 0.5468 - acc: 0.73491s - lo
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5536 - accuracy: 0.7278 - 291ms/epoch - 1ms/step
# Loss: 0.5535587668418884, Accuracy: 0.7278134226799011

# %%
# Final Attempt
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer. 
input_features_total = len(X_train_scaled[0]) 
hidden_nodes_layer1 = 30
hidden_nodes_layer2 = 40
hidden_nodes_layer3 = 50 #5
hidden_nodes_layer4 = 5
nn = tf.keras.models.Sequential() 
# First hidden layer 
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim = input_features_total, activation = "relu")) 
# Second hidden layer 
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation = "relu")) 
#Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation = "relu")) 
#Fourth Layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation = "relu"))
# Output layer 
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid")) 
# Check the structure of the model nn.summary()

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5773 - accuracy: 0.7168
# Epoch 2/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5544 - accuracy: 0.7278
# Epoch 3/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5507 - accuracy: 0.7297
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5482 - accuracy: 0.7326
# Epoch 5/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5474 - accuracy: 0.7317
# Epoch 6/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5454 - accuracy: 0.7322
# Epoch 7/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5454 - accuracy: 0.7329
# Epoch 8/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7337
# Epoch 9/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7344
# Epoch 10/50
# ...

# %%
nn.summary()
# Out:
# Model: "sequential_62"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_214 (Dense)           (None, 30)                3510
#
#  dense_215 (Dense)           (None, 40)                1240
#
#  dense_216 (Dense)           (None, 50)                2050
#
#  dense_217 (Dense)           (None, 5)                 255
#
#  dense_218 (Dense)           (None, 1)                 6
#
# ...
# Total params: 7061 (27.58 KB)
# Trainable params: 7061 (27.58 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5620 - accuracy: 0.7313 - 340ms/epoch - 1ms/step
# Loss: 0.5619801878929138, Accuracy: 0.7313119769096375

# %%
pwd
# Out:
# '/Users/Guara/Documents/Challenges/deep-learning-challenge'

# %% [markdown]
# ### Export our model to HDF5 file

# %%
path = '/Users/Guara/Documents/Challenges/deep-learning-challenge/Optimization.h5'
nn.save(path, save_format='h5')
